# %% [markdown]
# # What is an n-gram in text analysis?
#
# When you're performing text analysis, you usually stick to looking at individual words. Sometimes you need a little more specificity, or a little more context, and need to move to multi-word phrases. This is where ngrams come in.

# %% [markdown]
# <p class="reading-options">
#   <a class="btn" href="/azcentral-text-reuse-model-legislation/explaining-n-grams-in-natural-language-processing">
#     <i class="fa fa-sm fa-book"></i>
#     Read online
#   </a>
#   <a class="btn" href="/azcentral-text-reuse-model-legislation/notebooks/Explaining n-grams in Natural Language Processing.ipynb">
#     <i class="fa fa-sm fa-download"></i>
#     Download notebook
#   </a>
#   <a class="btn" href="#">
#     <i class="fa fa-sm fa-laptop"></i>
#     Interactive version
#   </a>
# </p>

# %% [markdown]
# ## Starting from the beginning
#
# Let's say we have some sentences.

# %%
sentences = [
    'Leopold ate the fish',
    'The fish ate Leopold',
    'Nora ate the fish',
    'The fish ate Nora',
    'Nora ate the bread',
]

# %% [markdown]
# Which ones are the most similar? With a little natural language processing, we can find out! We'll start by **counting the words.**

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.feature_extraction.text import TfidfVectorizer 

# We just want yes/no for our words, so we use binary=True
vectorizer = CountVectorizer(binary=True)
# Later, try uncommenting this line and see what happens to the chart below!
# vectorizer = TfidfVectorizer(use_idf=False)
matrix = vectorizer.fit_transform(sentences)
counts = pd.DataFrame(
    matrix.toarray(),
    index=sentences,
    columns=vectorizer.get_feature_names())
counts
# Out:
#                       ate  bread  fish  leopold  nora  the
# Leopold ate the fish    1      0     1        1     0    1
# The fish ate Leopold    1      0     1        1     0    1
# Nora ate the fish       1      0     1        0     1    1
# The fish ate Nora       1      0     1        0     1    1
# Nora ate the bread      1      1     0        0     1    1

# %% [markdown]
# We can see that "Leopold ate the fish" and "The fish ate Leopold" have all the same words, so they should definitely match up. Let's put a number to it to see how similar each of the sentences is:

# %%
counts.dot(counts.T) \
    .style \
    .background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col4 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col4 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_c0698be2_0ae4_11ea_9736_9801a7c3989d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Leopold ate the fish</th>        <th class="col_heading level0 col1" >The fish ate Leopold</th>        <th class="col_heading level0 col2" >Nora ate the fish</th>        <th class="col_heading level0 col3" >The fish ate Nora</th>        <th class="col_heading level0 col4" >Nora ate the bread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0698be2_0ae4_11ea_9736_9801a7c3989dlevel0_row0" class="row_heading level0 row0" >Leopold ate the fish</th>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col0" class="data row0 col0" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col1" class="data row0 col1" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col2" class="data row0 col2" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col3" class="data row0 col3" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow0_col4" class="data row0 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_c0698be2_0ae4_11ea_9736_9801a7c3989dlevel0_row1" class="row_heading level0 row1" >The fish ate Leopold</th>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col0" class="data row1 col0" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col1" class="data row1 col1" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col2" class="data row1 col2" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow1_col4" class="data row1 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_c0698be2_0ae4_11ea_9736_9801a7c3989dlevel0_row2" class="row_heading level0 row2" >Nora ate the fish</th>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col1" class="data row2 col1" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col2" class="data row2 col2" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col3" class="data row2 col3" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow2_col4" class="data row2 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c0698be2_0ae4_11ea_9736_9801a7c3989dlevel0_row3" class="row_heading level0 row3" >The fish ate Nora</th>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col1" class="data row3 col1" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col2" class="data row3 col2" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col3" class="data row3 col3" >4</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow3_col4" class="data row3 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c0698be2_0ae4_11ea_9736_9801a7c3989dlevel0_row4" class="row_heading level0 row4" >Nora ate the bread</th>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col0" class="data row4 col0" >2</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col2" class="data row4 col2" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col3" class="data row4 col3" >3</td>
#                         <td id="T_c0698be2_0ae4_11ea_9736_9801a7c3989drow4_col4" class="data row4 col4" >4</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Each sentence is very very similar to itself, so it gets a nice big score. "The fish ate Leopold" and "Leopold ate teh fish" have a full match between all the words, so they also get nice big scores.
#
# Here's the problem, though: **those sentences aren't similar in content at all!** I think that "Leopold ate the fish" and "Nora ate the fish" are far more similar, but they get a lower score.
#
# What makes those sentences the same or different? It isn't just the *words* they have, it's *context*, it's *the order the words show up in.*
#
# > Technically speaking, just basing analysis on the words is called "bag of words," because it's like you threw all the words into a bag and shook them up!
#
# Instead of just counting the words, we have an alternative: count **phrases**. That way we can see when "ate the fish" repeats.
#
# These phrases are called n-grams, where *n* is the number of words you're looking at. 1-grams are one word, 2-grams are two words, 3-grams are three words. You can also call them unigrams, bigrams or trigrams, if you're feeling fancy.
#
# Let's use the same code we did before, but throw in an additional option.

# %%
# We just want yes/no for our words, so we use binary=True
vectorizer = CountVectorizer(binary=True, ngram_range=(3,3))
# Later, try uncommenting this line and see what happens to the chart below!
# vectorizer = TfidfVectorizer(use_idf=False, ngram_range=(3,3))
matrix = vectorizer.fit_transform(sentences)
counts = pd.DataFrame(
    matrix.toarray(),
    index=sentences,
    columns=vectorizer.get_feature_names())
counts
# Out:
#                       ate the bread  ate the fish  fish ate leopold  \
# Leopold ate the fish              0             1                 0
# The fish ate Leopold              0             0                 1
# Nora ate the fish                 0             1                 0
# The fish ate Nora                 0             0                 0
# Nora ate the bread                1             0                 0
#
#                       fish ate nora  leopold ate the  nora ate the  \
# Leopold ate the fish              0                1             0
# The fish ate Leopold              0                0             0
# Nora ate the fish                 0                0             1
# The fish ate Nora                 1                0             0
# Nora ate the bread                0                0             1
#
#                       the fish ate
# Leopold ate the fish             0
# The fish ate Leopold             1
# Nora ate the fish                0
# The fish ate Nora                1
# Nora ate the bread               0

# %% [markdown]
# Now we're only counting **three word phrases**, aka **trigrams**. If we use these counts to compute the similarity between each of the sentences, we feel... kind of better?

# %%
counts.dot(counts.T) \
    .style \
    .background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col4 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_c0c75614_0ae4_11ea_af86_9801a7c3989d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Leopold ate the fish</th>        <th class="col_heading level0 col1" >The fish ate Leopold</th>        <th class="col_heading level0 col2" >Nora ate the fish</th>        <th class="col_heading level0 col3" >The fish ate Nora</th>        <th class="col_heading level0 col4" >Nora ate the bread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0c75614_0ae4_11ea_af86_9801a7c3989dlevel0_row0" class="row_heading level0 row0" >Leopold ate the fish</th>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col0" class="data row0 col0" >2</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c0c75614_0ae4_11ea_af86_9801a7c3989dlevel0_row1" class="row_heading level0 row1" >The fish ate Leopold</th>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow1_col4" class="data row1 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c0c75614_0ae4_11ea_af86_9801a7c3989dlevel0_row2" class="row_heading level0 row2" >Nora ate the fish</th>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col2" class="data row2 col2" >2</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col3" class="data row2 col3" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c0c75614_0ae4_11ea_af86_9801a7c3989dlevel0_row3" class="row_heading level0 row3" >The fish ate Nora</th>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col2" class="data row3 col2" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col3" class="data row3 col3" >2</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow3_col4" class="data row3 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c0c75614_0ae4_11ea_af86_9801a7c3989dlevel0_row4" class="row_heading level0 row4" >Nora ate the bread</th>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col2" class="data row4 col2" >1</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col3" class="data row4 col3" >0</td>
#                         <td id="T_c0c75614_0ae4_11ea_af86_9801a7c3989drow4_col4" class="data row4 col4" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# First off, the good thing: "Leopold ate the fish" and "Nora ate the fish" are now showing up as matches!
#
# But then there's the bad thing: "The fish ate Leopold" is certainly a *little* similar to "Leopold ate the fish," but it shows up as not matching at all. What a crisis!!!
#
# One more attempt: instead of just looking at 1-grams or 3-grams, we can look at 1-grams, 2-grams, and 3-grams, *all at the same time.*

# %%
# We have more columns than we're used to, so I'm increasing the number pandas will display.
pd.set_option("display.max_columns", 30)

# We just want yes/no for our words, so we use binary=True
vectorizer = CountVectorizer(binary=True, ngram_range=(1,3))
# Later, try uncommenting this line and see what happens to the chart below!
# vectorizer = TfidfVectorizer(use_idf=False, ngram_range=(1,3))
matrix = vectorizer.fit_transform(sentences)
counts = pd.DataFrame(
    matrix.toarray(),
    index=sentences,
    columns=vectorizer.get_feature_names())
counts
# Out:
#                       ate  ate leopold  ate nora  ate the  ate the bread  \
# Leopold ate the fish    1            0         0        1              0
# The fish ate Leopold    1            1         0        0              0
# Nora ate the fish       1            0         0        1              0
# The fish ate Nora       1            0         1        0              0
# Nora ate the bread      1            0         0        1              1
#
#                       ate the fish  bread  fish  fish ate  fish ate leopold  \
# Leopold ate the fish             1      0     1         0                 0
# The fish ate Leopold             0      0     1         1                 1
# Nora ate the fish                1      0     1         0                 0
# The fish ate Nora                0      0     1         1                 0
# Nora ate the bread               0      1     0         0                 0
#
#                       fish ate nora  leopold  leopold ate  leopold ate the  \
# Leopold ate the fish              0        1            1                1
# The fish ate Leopold              0        1            0                0
# Nora ate the fish                 0        0            0                0
# The fish ate Nora                 1        0            0                0
# Nora ate the bread                0        0            0                0
#
#                       nora  nora ate  nora ate the  the  the bread  the fish  \
# Leopold ate the fish     0         0             0    1          0         1
# The fish ate Leopold     0         0             0    1          0         1
# Nora ate the fish        1         1             1    1          0         1
# The fish ate Nora        1         0             0    1          0         1
# Nora ate the bread       1         1             1    1          1         0
#
#                       the fish ate
# Leopold ate the fish             0
# The fish ate Leopold             1
# Nora ate the fish                0
# The fish ate Nora                1
# Nora ate the bread               0

# %% [markdown]
# We have a lot lot lot more columns, maybe more than we can easily judge by the eye, but that's why we have that nice colorful chart!

# %%
counts.dot(counts.T) \
    .style \
    .background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col2 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col0 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col3 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col4 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col0 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Leopold ate the fish</th>        <th class="col_heading level0 col1" >The fish ate Leopold</th>        <th class="col_heading level0 col2" >Nora ate the fish</th>        <th class="col_heading level0 col3" >The fish ate Nora</th>        <th class="col_heading level0 col4" >Nora ate the bread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989dlevel0_row0" class="row_heading level0 row0" >Leopold ate the fish</th>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col0" class="data row0 col0" >9</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col1" class="data row0 col1" >5</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col2" class="data row0 col2" >6</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col3" class="data row0 col3" >4</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow0_col4" class="data row0 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989dlevel0_row1" class="row_heading level0 row1" >The fish ate Leopold</th>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col0" class="data row1 col0" >5</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col1" class="data row1 col1" >9</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col2" class="data row1 col2" >4</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col3" class="data row1 col3" >6</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow1_col4" class="data row1 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989dlevel0_row2" class="row_heading level0 row2" >Nora ate the fish</th>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col0" class="data row2 col0" >6</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col1" class="data row2 col1" >4</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col2" class="data row2 col2" >9</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col3" class="data row2 col3" >5</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow2_col4" class="data row2 col4" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989dlevel0_row3" class="row_heading level0 row3" >The fish ate Nora</th>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col1" class="data row3 col1" >6</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col2" class="data row3 col2" >5</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col3" class="data row3 col3" >9</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow3_col4" class="data row3 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989dlevel0_row4" class="row_heading level0 row4" >Nora ate the bread</th>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col0" class="data row4 col0" >3</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col1" class="data row4 col1" >2</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col2" class="data row4 col2" >6</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col3" class="data row4 col3" >3</td>
#                         <td id="T_c18a8828_0ae4_11ea_b8e3_9801a7c3989drow4_col4" class="data row4 col4" >9</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Looking good! Comparisons are made based on single words, sure, but also on larger phrases up to 3 words long. Even though it takes a lot more columns of data, I think it does a much better job of allowing us to make useful comparisons between sentences.

# %% [markdown]
# # Review
#
# Text analysis often deals with words individually, ignoring the order they come in. This is called the **bag of words** technique. While this is a simple technique, it turns out you lose some of the meaning of a sentence when you look at words in isolation.
#
# To solve this, we turned to the idea of **n-grams**, where you use combinations of 2- or 3- or even more words instead of just looking at them individually. It ends up creating more data for you to deal with (and possibly more processing time), but it does allow your code to make more nuance comparisons with the text.
